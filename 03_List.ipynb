# %% [markdown]
# # Lists:

# %% [markdown]
# You can use these when you need a collection of similar/non similar items. Suppose you are making a program that randomly picks a name from a hat. You could do something like this:

# %% [markdown]
# ### in square brackets [ ]
# ### sequential- It has oredering and index
# index starts from 0
# ### mutable
# ### Contains any kind of data
# Example of list <br>
# list1=[1,2,3]<br>
# listexample = [17, 123, "python", [1,2,3], 6.0]<br>
#
# s="python"

# %%
list1=[1,2,3]
listexample = [17, 123, "python", list1, 6.0]
listexample

# %%
a=[]
type(a)
# Out:
# list

# %%
a=list()
print(type(a))
print(a)
# Out:
# <class 'list'>
# []

# %%
n = [17, 123, "python", "java", [1,2,3], 6.0]
n
# Out:
# [17, 123, 'python', 'java', [1, 2, 3], 6.0]

# %%
type (n)
# Out:
# list

# %%
len(n)
# Out:
# 6

# %%
n[0]
# Out:
# 17

# %%
n[4]
# Out:
# [1, 2, 3]

# %%
n[3][0]
# Out:
# 'j'

# %%
n[4][1]
# Out:
# 2

# %%
numbers = [715555, "123", "python", "java", [1,2,3], 6.0]
#            0    1     2          3       4      5

# %%
numbers[1][0]
# Out:
# '1'

# %%
numbers[0][0]
# s="213"
# s[0]
# iterable object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ae15ae5d48d4> in <module>
# ----> 1 numbers[0][0]
#       2 # s="213"
#       3 # s[0]
#       4 # iterable object
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# # Mutable
# List is mutable object

# %%
s="python"
s[0]="q"
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8e8a019b9b6f> in <module>
#       1 s="python"
# ----> 2 s[0]="q"
#       3 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
numbers=[500, 123, 'python', 'java', ['javascript', 2, 3], 6.0]
numbers[0]=200
print(numbers)
# Out:
# [200, 123, 'python', 'java', ['javascript', 2, 3], 6.0]

# %%
numbers[2][0]="q"
numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a47683246188> in <module>
# ----> 1 numbers[2][0]="q"
#       2 numbers
#
# TypeError: 'str' object does not support item assignment

# %%
numbers[2]="q"
numbers
# Out:
# [200, 123, 'q', 'java', ['javascript', 2, 3], 6.0]

# %%
numbers[4][0]="C++"
numbers
# Out:
# [200, 123, 'q', 'java', ['C++', 2, 3], 6.0]

# %%
numbers=[200, 123, 'python', 'java', ['q', 2, 3], 6.0]

# %%
l1=[1,2,3]
l2=l1.copy()
l2
# Out:
# [1, 2, 3]

# %%
l1==l2
# Out:
# True

# %%
l1 is l2
# Out:
# False

# %%
list1=[45,89,0]
list2=list1
print(list2)
print(list1==list2)
# Out:
# [45, 89, 0]
# True

# %%
print(list1 is list2)
# Out:
# True

# %%
dir(list)

# %%
help(numbers)

# %% [markdown]
# ### Append
# It adds the element at the end of a list

# %%
numbers = [17, "java", [1,2,3]]
numbers.append("python")
print(numbers)
# Out:
# [17, 'java', [1, 2, 3], 'python']

# %%
numbers.append([0,1,2])
numbers
# Out:
# [17, 'java', [1, 2, 3], 'python', [0, 1, 2]]

# %%
numbers.append(1)
numbers
# Out:
# [17, 'java', [1, 2, 3], 'python', [0, 1, 2], 1]

# %% [markdown]
# ### Extend
# It adds at the end , but only iterable objects...
# It seprateout the iterable object in the individual element and than it will add.

# %%
numbers = [17, "java", [1,2,3]]
numbers.extend("python")
numbers
# Out:
# [17, 'java', [1, 2, 3], 'p', 'y', 't', 'h', 'o', 'n']

# %%
numbers.extend([100,101,102])
numbers
# Out:
# [17, 'java', [1, 2, 3], 'p', 'y', 't', 'h', 'o', 'n', 100, 101, 102]

# %%
numbers
# Out:
# [17, 'java', [1, 2, 3], 'p', 'y', 't', 'h', 'o', 'n', 100, 101, 102]

# %%
numbers.extend(123)
numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-e7d907ddec2f> in <module>
# ----> 1 numbers.extend(123)
#       2 numbers
#
# TypeError: 'int' object is not iterable

# %%
numbers.extend("a")
numbers
# Out:
# [17, 'java', [1, 2, 3], 'p', 'y', 't', 'h', 'o', 'n', 100, 101, 102, 'a']

# %%
numbers.extend("12")
numbers
# Out:
# [17,
#  'java',
#  [1, 2, 3],
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  100,
#  101,
#  102,
#  'a',
#  '1',
#  '2']

# %% [markdown]
# # Pop- Removes and returns, so that we are not loosing that value

# %%
list1=[0,1898,100,2,3,"python","jaava"]

# %%
x=list1.pop() # remove last element  of list if we do not mention index
print(" The popped element x is : ",x)
print (" After Pop the changed the list is ",list1)
# Out:
#  The popped element x is :  jaava
#  After Pop the changed the list is  [0, 1898, 100, 2, 3, 'python']

# %%
list1=[0,1898,100,2,3,"python","scala"]
x=list1.pop()
print(list1)
# Out:
# [0, 1898, 100, 2, 3, 'python']

# %%
list1=[0,1898,100,2,3,"python","jaava"]

# %%
x=list1.pop(1)
print(" The popped element is : ",x)
print (" After Pop the changed the list is ",list1)
# Out:
#  The popped element is :  1898
#  After Pop the changed the list is  [0, 100, 2, 3, 'python', 'jaava']

# %%
list1

# %%
a=[100,1,200,2,3,"python","jaava",[1,2]]
a.remove("python")
print (" After remove the changed the list is ",a)
# Out:
#  After remove the changed the list is  [100, 1, 200, 2, 3, 'jaava', [1, 2]]

# %%
a.remove([1,2])
a
# Out:
# [100, 1, 200, 2, 3, 'jaava']

# %%
a=[0,1,0,2,3,"python","jaava",[1,2,3]]
a.reverse()
print(a)
# Out:
# [[1, 2, 3], 'jaava', 'python', 3, 2, 0, 1, 0]

# %%
How to reverse a string??
s[::-1]

# %% [markdown]
# # Sorting ( Ascending order)
#
# # number < capital letter < small letter

# %%
a=["Python","1python"]
a.sort()
a
# Out:
# ['1python', 'Python']

# %%
a=['scala','jaava', 'python']
a.sort()
a
# Out:
# ['jaava', 'python', 'scala']

# %%
a=['scala','jaava','123', 'Python','Java']
a.sort()
a
# Out:
# ['123', 'Java', 'Python', 'jaava', 'scala']

# %%
a=['scala','jaava',23, 'Python']
a.sort()
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b7468b9667f1> in <module>
#       1 a=['scala','jaava',23, 'Python']
# ----> 2 a.sort()
#       3 a
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
a=[100,23, 500]
a.sort()
a
# Out:
# [23, 100, 500]

# %%
a=[100,23, 500]
a.sort(reverse=True)
a
# a    L.sort(key=None, reverse=False) -> None -- stable sort *IN PLACE*
# Out:
# [500, 100, 23]

# %% [markdown]
# # string --> list
# # list----> string
#
# # split
# # join

# %%
s="python"
list1= ['p', 'y', 't', 'h' ,'o' ,'n']

# %%
l=['1','2','4']#'124'
''.join(l)
# Out:
# '124'

# %%
l=['1','2','4']#'124'
' '.join(l)
# Out:
# '1 2 4'

# %%
list1= ['p', 'y', 't', 'h' ,'o' ,'n']
'**'.join(list1)
# Out:
# 'p**y**t**h**o**n'

# %%
'$$$'.join(list1)
# Out:
# 'p$$$y$$$t$$$h$$$o$$$n'

# %%
list1= ['p', 'y', 't', 'h' ,'o' ,'n', ["asd"]]
'**'.join(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-0d03fec94317> in <module>
#       1 list1= ['p', 'y', 't', 'h' ,'o' ,'n', ["asd"]]
# ----> 2 '**'.join(list1)
#
# TypeError: sequence item 6: expected str instance, list found

# %%
a=["python","jaava","scala"]
''.join(a)
# Out:
# 'pythonjaavascala'

# %%
' '.join(a)
# Out:
# 'python jaava scala'

# %%
s='$$*'.join(a)
print(s)
# Out:
# python$$*jaava$$*scala

# %%
print(' : '.join(a))

# %%
s = "python : jaava : scala"
l=s.split(' : ')
print(l)
# Out:
# ['python', 'jaava', 'scala']

# %%
s = "python : jaava : scala"
l=s.split(' ')
l
# Out:
# ['python', ':', 'jaava', ':', 'scala']

# %%
s= 'python$$*jaava$$*scala'
print(s.split('$$*'))
# Out:
# ['python', 'jaava', 'scala']

# %%
s1= '123'
print(s1.split('2'))
# Out:
# ['1', '3']

# %%
list1=["javascript","java","python", "scala",'1']
list1[0:3]
# Out:
# ['javascript', 'java', 'python']

# %%
list1[:4]
# Out:
# ['javascript', 'java', 'python', 'scala']

# %%
list1[::-1]
# Out:
# ['1', 'scala', 'python', 'java', 'javascript']

# %%
lis = [2, 1, 3, 5, 4]
# using min() to print minimum element of list
# print ("The minimum element of list is : ", end="")
print (min(lis))
# Out:
# 1

# %%
lis = [2, 1, 3, 5, 4.0, "abc"]
min(lis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-bef22dc58ced> in <module>
#       1 lis = [2, 1, 3, 5, 4.0, "abc"]
# ----> 2 min(lis)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
lis = [2, 1, 3, 5, 4.0]
max(lis)
# Out:
# 5

# %%
lis = [2, 1, 3, 5, 4.0]
sum(lis)
# Out:
# 15.0

# %%
lis = ['2', '1','3']
max(lis)
# Out:
# '3'

# %%
lis = ['a', 'b','c']
max(lis)
# Out:
# 'c'

# %%
# number < capital letter < small letter
lis = ['2', '1','3',"abc",'A']
max(lis)
# Out:
# 'abc'

# %%
min(lis)

# %%
lis = [2, 1,3]
# lis = ['abc', 'def','ghi']
sum(lis)

# %%
ListData = [1, 2, 3, 1, 2, 1, 2, 3, 2, 1,"python"]
ListData.index("python")
# ListData.index(1)
# Out:
# 10

# %%
lis = [1, 4, 3, 2, 5]
4 in lis
# Out:
# True

# %%
4 not in lis
# Out:
# False

# %%
"p" in "python"
# Out:
# True

# %%
"r" in "python"
# Out:
# False

# %%
l1=[1,2,3]
l2=[1,2,3]
print(l1 is l2)
print(l1==l2)

# %%
print(id(l1))
print(id(l2))

# %%
l1=[1,2,3]
l2=l1
print(l1 is l2)
print(l1==l2)
# Out:
# True
# True

# %%
li1 = [4, 8, 2, 10, 15, 18] 
li_copy = li1[:] 
print("Original List:", li1) 
print("After Cloning:", li_copy) 
print(li1 is li_copy)
print(li_copy==li1)
# Out:
# Original List: [4, 8, 2, 10, 15, 18]
# After Cloning: [4, 8, 2, 10, 15, 18]
# False
# True

# %%
v = [0,0,0,0,0,0,0,0,0]
vec=v
v[5]=5
# and this changes both v and vec:
print (vec)

# %%
a = [7, 3, 4]
b = a
c = a[:]# c=[7,3,4]
b[0] = 10
print ('a: ', a, id(a))
print ('b: ', b, id(b))
print ('c: ', c, id(c))
# Out:
# a:  [10, 3, 4] 2617429371016
# b:  [10, 3, 4] 2617429371016
# c:  [7, 3, 4] 2617429371912

# %%
alist = [7, 3, 4]
blist = list(alist)
print ('alist: ', alist, id(blist))
print ('blist: ', blist, id(alist))

# %% [markdown]
# # Assignment
# * For a list ["foo", "bar", "baz"] add an item in the list "bar",
#  what's the cleanest way to get its index (1) in Python?
# * Best way to check if a list is empty
# * Getting the last element of a list in Python
# * How to clone or copy a list?
# * How can I count the occurrences of a list item in Python?
# * How do I remove the first Item from a Python list?
# * Write a program to create a buffer of length 5

# %%
vlans1=['!command:', '!Time','version....','valanc....','....','valna 130', 'name AHKZMI' , 'mode fabricapath' ]
vlans2=['!command:', '!Time','version....','valanc....','....','valna 130', 'name AHKZMI' , 'mode fabricapath' ]

for x in vlans1 :
    if vlans1[x]==vlans2[x]:
        print ("its matching")
    else:
        print (vlans1[x] + 'and' +'vlans2[x]'+ " is not matching ")
        break

# %%
vlans1=[' sh run vlan 159\r', '', '!Command: show running-config vlan 159', '!Time: Sat Jul  7 00:40:22 2018', '', 'version 7.1(4)N1(1c)', 'vlan configuration 159', '', '\rKC1DD10-RED#']
vlans2=[' sh run vlan 159\r', '', '!Command: show running-config vlan 159', '!Time: Sat Jul  7 00:40:25 2018', '', 'version 7.1(4)N1(1c)', 'vlan configuration 159', 'vlan 159', '  name MCVHVA_RAC', '  mode fabricpath', '', '\rKC1DD10-BLUE#']


common_elements=[]
for i in list(itertools.product(a,b)):
    if i[0] == i[1]:
        common_elements.append(i[0])
print (common_elenents)
        
        
        
# def vlan_comp(switch,switch2):
#     print ("I am in side compare function")
# #     print (switch)
# #     print(switch2)
#     missing = []
# #     for x in switch:
# #         print (x)
#     for x in range(len(switch)-1):
#         match = False
        
#         if switch[x] == switch2[x]:
#                 match = True
#         if match == False:
#             missing.append(switch[x] +"is not matching with "+ switch2[x])
#     return missing


# result1 = vlan_comp(vlans2,vlans1)
# result2 = vlan_comp(vlans1,vlans2)
# # print "switch1 : " ,switch1
# # print "switch1 : " ,switch1

# %%
a=[' sh run vlan 159\r', '', '!Command: show running-config vlan 159', '!Time: Sat Jul  7 00:40:22 2018', '', 'version 7.1(4)N1(1c)', 'vlan configuration 159', '', '\rKC1DD10-RED#']
b=[' sh run vlan 159\r', '', '!Command: show running-config vlan 159', '!Time: Sat Jul  7 00:40:25 2018', '', 'version 7.1(4)N1(1c)', 'vlan configuration 159', 'vlan 159', '  name MCVHVA_RAC', '  mode fabricpath', '', '\rKC1DD10-BLUE#']

def returnNotMatches(a, b):
    a = set(a)
    b = set(b)
    return list(b - a)


switch name is 
l=returnNotMatches(a, b)
print( "-----------the configuration differene from a to b is------- ")
print ('\n'.join(l))
l2= returnNotMatches(b, a)
print( "--------------the configuration differene from b to a is--------- ")
print ('\n'.join(l2))
