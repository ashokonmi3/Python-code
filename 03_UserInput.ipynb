# %% [markdown]
# ### User INPUT

# %%
x=input("Enter data for input type for testing ")
print (type(x))
print (x)
# y=type(x)
# x=input(" ")
# print (str(y))
# if (str(y)=="<class \'str\'>"):
#     print ("its string")
# else: print("not string")
# Out:
# Enter data for input type for testing 67.0
# <class 'str'>
# 67.0

# %%
x=input("Enter data for reverse ")
print ("Reverse of string is : ", x[::-1])
# Out:
# Enter data for reverse python
# Reverse of string is :  nohtyp

# %%
print("How old are you")
age =input ()
print ("How tall are you")
height=input()
print ("How much do you weight")
weight=input()
print ("So you are %s years old, %s tall and weigh %s" %(age,height,weight))
# Out:
# How old are you
# 67
# How tall are you
# 66
# How much do you weight
# 55
# So you are 67 years old, 66 tall and weigh 55

# %%
print ("hello")
# print("Hello, ", end="\n")
# 
print("worlds")
print("python")
# Out:
# hello
# worlds
# python

# %%
print("Hello, ", end="break ")
print("world")
print("python")
# Out:
# Hello, break world
# python

# %%
print("Hello, ", end="\n")
print("world")
# Out:
# Hello,
# world

# %%
print("Hello, ", end=" BREAK ")
print("world", end=" python ")
print("Selenium")
print("Learning")
# Out:
# Hello,  BREAK world python Selenium
# Learning

# %% [markdown]
# ### TYPE CASTING
# Converting one data type to another data type

# %%
i=23
# '23'

# %%
j=str(i)#'23'
print (j)
print (type(j))
# Out:
# 23
# <class 'str'>

# %%
print (j[0])
print (j[1])
#'23'
# Out:
# 2
# 3

# %%
i=10.0
j=str(i)
print (type(j))
print (j)
# Out:
# <class 'str'>
# 10.0

# %%
# j="10.0"
print (j[0])
print (j[1])
print (j[2])
print (j[3])
# Out:
# 1
# 0
# .
# 0

# %%
# print (int("Hello World"))
print (int("H"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-96354cb293cb> in <module>()
#       1 # print (int("Hello World"))
# ----> 2 print (int("H"))
#
# ValueError: invalid literal for int() with base 10: 'H'

# %%
st="1000"

# %%
x=int(st)
print (x)
# Out:
# 1000

# %%
s=100.6

# %%
int(s)
# Out:
# 100

# %%
s="1000.0"

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-2c4720ab420a> in <module>()
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: '1000.0'

# %%
int(.)
# Out:
#   File "<ipython-input-24-3d92899f7998>", line 1
#     int(.)
#         ^
# SyntaxError: invalid syntax

# %%
i=1000
j=float(1000)
print(j)
# Out:
# 1000.0

# %%
s="1000.0"
j=float(s)
print(j)
# Out:
# 1000.0
